# %%
#calculation of piotroski-F score
from yahooquery import Ticker

symbol = "MRF.NS"
stock  = Ticker(symbol)

info = stock.asset_profile

info
# Out:
# {'MRF.NS': {'address1': 'No. 114, Greams Road',
#   'city': 'Chennai',
#   'zip': '600006',
#   'country': 'India',
#   'phone': '91 44 2829 2777',
#   'fax': '91 44 2829 5087',
#   'website': 'https://www.mrftyres.com',
#   'industry': 'Auto Parts',
#   'industryDisp': 'Auto Parts',
#   'sector': 'Consumer Cyclical',
#   'longBusinessSummary': 'MRF Limited, together with its subsidiaries, manufactures, sells, and trades in rubber products in India and internationally. The company provides rubber products, such as tires, tubes, flaps, and tread rubber; tires for trucks, farm vehicles, LCVs, SCVs, MCVs, three wheelers, pick up, two wheelers, passenger cars, and OTRs; and manufactures specialty coatings. It is also involved in the paints and coats, toys, motorsports, and cricket training businesses. In addition, the company operates MRF T&S, MRF TireTok, MRF Tyredrome, MRF FASST, MRF Musclezone, and shops that provide computerized nitrogen inflation, tubeless repair, wheel alignment, wheel balancing and tyre changing, robotic wheel alignment, vehicle safety test lane, diagnostic wheel balancing, A/C recovery and recharging, headlight alignment, nitrogen generation, special two-wheeler tyre changing, credit card facility, wheels removal and refitment, and tyre mounting and de-mounting services. MRF Limited sells its products through approximately 5,000 dealer networks. The company was founded in 1946 and is based in Chennai, India.',
#   'companyOfficers': [{'maxAge': 1,
#     'name': 'Mr. K. M. Vinoo Mammen',
#     'age': 73,
#     'title': 'Chairman & MD',
#     'yearBorn': 1949,
#     'fiscalYear': 2022,
#     'totalPay': 260405110,
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Mr. Arun  Mammen B.Com., M.B.A.',
#     'age': 56,
#     'title': 'MD & Vice Chairman',
#     'yearBorn': 1966,
#     'fiscalYear': 2022,
#     'totalPay': 217457449,
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Mr. Rahul Mammen Mappillai',
#     'age': 44,
#     'title': 'Managing Director',
#     'yearBorn': 1978,
#     'fiscalYear': 2022,
#     'totalPay': 200713659,
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Mr. Samir Thariyan Mappillai',
#     'age': 40,
#     'title': 'Whole-Time Director',
#     'yearBorn': 1982,
#     'fiscalYear': 2022,
#     'totalPay': 56864064,
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Mr. Varun  Mammen',
#     'age': 39,
#     'title': 'Whole-Time Director',
#     'yearBorn': 1983,
#     'fiscalYear': 2022,
#     'totalPay': 57035599,
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Mr. Madhu P. Nainan',
#     'age': 54,
#     'title': 'VP of Fin.',
#     'yearBorn': 1968,
#     'fiscalYear': 2020,
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Mr. S. Dhanvanth Kumar A.C.S., B.Com., M.B.A.',
#     'title': 'Company Sec. & Compliance Officer',
#     'fiscalYear': 2020,
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Mr. Raman  Kumar M.Sc.',
#     'age': 73,
#     'title': 'VP of Sales',
#     'yearBorn': 1949,
#     'fiscalYear': 2006,
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Mrs. Meera  Mammen M.A',
#     'age': 66,
#     'title': 'VP of Welfare',
#     'yearBorn': 1956,
#     'fiscalYear': 2006,
#     'exercisedValue': 0,
#     'unexercisedValue': 0}],
#   'compensationAsOfEpochDate': '2022-12-31 05:30:00',
#   'maxAge': 86400}}

# %%
bs = stock.balance_sheet()

# %%
cf = stock.cash_flow(trailing=False)
cf
# Out:
#          asOfDate periodType currencyCode  BeginningCashPosition  \
# symbol
# MRF.NS 2020-03-31        12M          INR           1.019500e+09
# MRF.NS 2021-03-31        12M          INR           1.178520e+10
# MRF.NS 2022-03-31        12M          INR           1.668500e+09
# MRF.NS 2023-03-31        12M          INR           2.543900e+09
#
#         CapitalExpenditure  CashDividendsPaid  \
# symbol
# MRF.NS       -2.752360e+10       -306800000.0
# MRF.NS       -8.527400e+09       -424100000.0
# MRF.NS       -1.707010e+10       -636000000.0
# MRF.NS       -3.291240e+10       -636200000.0
#
#         ChangeInCashSupplementalAsReported  ChangeInInventory  \
# symbol
# MRF.NS                        1.076570e+10       8.802000e+08
# MRF.NS                       -1.011320e+10      -3.363000e+08
# MRF.NS                        1.074000e+08      -1.190860e+10
# MRF.NS                       -7.540000e+07      -1.138000e+08
#
#         ChangeInOtherCurrentLiabilities  ChangeInPayable  ...  \
# symbol                                                    ...
# MRF.NS                    -7.237000e+08     1.879200e+09  ...
# MRF.NS                     2.105300e+09     1.588240e+10  ...
# MRF.NS                     2.201400e+09    -1.249850e+10  ...
# MRF.NS                     3.492700e+09     3.797200e+09  ...
#
#         NetPPEPurchaseAndSale  NetShortTermDebtIssuance  OperatingCashFlow  \
# symbol
# MRF.NS          -2.749890e+10             -3.130200e+09       2.272610e+10
# MRF.NS          -8.515900e+09              1.844400e+09       4.324580e+10
# MRF.NS          -1.704640e+10              7.859400e+09      -5.780300e+09
# MRF.NS          -3.290060e+10             -2.545300e+09       2.755470e+10
#
#         OtherNonCashItems  PurchaseOfInvestment  PurchaseOfPPE  \
# symbol
# MRF.NS       2.708800e+09         -2.065740e+10  -2.752360e+10
# MRF.NS       1.457100e+09         -6.218070e+10  -8.527400e+09
# MRF.NS       1.523200e+09         -1.253000e+10  -1.707010e+10
# MRF.NS       2.118200e+09         -1.359900e+09  -3.291240e+10
#
#         RepaymentOfDebt  SaleOfInvestment   SaleOfPPE  TaxesRefundPaid
# symbol
# MRF.NS    -4.025600e+09      4.650900e+10  24700000.0    -4.418100e+09
# MRF.NS    -3.409200e+09      1.887250e+10  11500000.0    -5.167700e+09
# MRF.NS    -2.660000e+09      3.033020e+10  23700000.0    -2.134600e+09
# MRF.NS    -2.885900e+09      1.387190e+10  11800000.0    -3.277700e+09
#
# [4 rows x 47 columns]

# %%
fin = stock.all_financial_data()
fin
# Out:
#          asOfDate periodType currencyCode  AccountsPayable  \
# symbol
# MRF.NS 2020-03-31        12M          INR     1.905340e+10
# MRF.NS 2021-03-31        12M          INR     3.531460e+10
# MRF.NS 2022-03-31        12M          INR     2.133010e+10
# MRF.NS 2023-03-31        12M          INR     2.435770e+10
#
#         AccountsReceivable  AccumulatedDepreciation  AdditionalPaidInCapital  \
# symbol
# MRF.NS        2.299400e+10            -3.459880e+10               98600000.0
# MRF.NS        2.254260e+10            -4.600820e+10               98600000.0
# MRF.NS        2.332680e+10            -5.728020e+10               98600000.0
# MRF.NS        2.503270e+10                      NaN                      NaN
#
#         AllowanceForDoubtfulAccountsReceivable  AssetsHeldForSaleCurrent  \
# symbol
# MRF.NS                             -27600000.0                       0.0
# MRF.NS                             -32400000.0                       NaN
# MRF.NS                             -29900000.0                       NaN
# MRF.NS                                     NaN                       NaN
#
#         AvailableForSaleSecurities  ...  \
# symbol                              ...
# MRF.NS                7.815000e+08  ...
# MRF.NS                1.195580e+10  ...
# MRF.NS                1.253920e+10  ...
# MRF.NS                1.137170e+10  ...
#
#         TotalNonCurrentLiabilitiesNetMinorityInterest  TotalOtherFinanceCost  \
# symbol
# MRF.NS                                   1.975260e+10             83000000.0
# MRF.NS                                   1.900400e+10             77600000.0
# MRF.NS                                   2.071110e+10             94600000.0
# MRF.NS                                   2.166270e+10                    NaN
#
#         TotalRevenue  TotalTaxPayable  TotalUnusualItems  \
# symbol
# MRF.NS  1.616215e+11       28100000.0       2.513100e+09
# MRF.NS  1.607667e+11       37600000.0       2.457000e+08
# MRF.NS  1.902715e+11       38200000.0       1.529400e+09
# MRF.NS  2.300850e+11       36700000.0                NaN
#
#         TotalUnusualItemsExcludingGoodwill  TradeandOtherPayablesNonCurrent  \
# symbol
# MRF.NS                        2.513100e+09                      929900000.0
# MRF.NS                        2.457000e+08                       98500000.0
# MRF.NS                        1.529400e+09                      169000000.0
# MRF.NS                                 NaN                              NaN
#
#         WorkInProcess  WorkingCapital   WriteOff
# symbol
# MRF.NS   2.335000e+09    2.898800e+10  2500000.0
# MRF.NS   3.263600e+09    3.099530e+10  6400000.0
# MRF.NS   3.952900e+09    3.231220e+10  6300000.0
# MRF.NS            NaN    1.748360e+10        NaN
#
# [4 rows x 178 columns]

# %%
ni = cf["NetIncome"][0]
ni
# Out:
# 14225600000.0

# %%
def roa():
    c_tca = bs["TotalAssets"][0]
    c_tl = bs["TotalLiabilitiesNetMinorityInterest"][0]
    c_roa = c_tca/c_tl
    return c_roa

def ocf():
    try:
        c_ocf = int(cf["OperatingCashFlow"][0])
        return c_ocf
    except KeyError:
        c_ocf = 0
        return c_ocf

# %%
def current_ratio():
    c_tca = fin["CurrentAssets"][0]
    py_tca = fin["CurrentAssets"][1]
    c_tl = bs["CurrentLiabilities"][0]
    py_tl = bs["CurrentLiabilities"][1]
    r1 = c_tca/c_tl
    r2 = py_tca/py_tl
    if r1 > r2:
        return 1
    else:
        return 0

def gross_margin():
    c_gm = fin["GrossProfit"][0]
    py_gm = fin["GrossProfit"][1]
    return c_gm - py_gm

def at_ratio():
    c_assets = fin["TotalAssets"][0]
    py1_assets = fin["TotalAssets"][1]
    py2_assets = fin["TotalAssets"][2]
    av1 = (c_assets+py1_assets)/2
    av2 = (py1_assets+py2_assets)/2
    atr1 = fin["TotalRevenue"][0]/av1
    atr2 = fin["TotalRevenue"][1]/av2
    return atr1-atr2

def new_shares():
    c_ns = fin['CommonStock'][0]
    py_ns = bs['CommonStock'][1]
    if c_ns - py_ns == 0:
        return 1
    else:
        return 0

def lt_debt():
    try:
        c_lt_debt = bs["NonCurrentDeferredLiabilities"][0]
    except KeyError:
        c_lt_debt = 0
    try:
        py_lt_debt = bs["NonCurrentDeferredLiabilities"][1]
    except KeyError:
        py_lt_debt = 0

    if c_lt_debt < py_lt_debt:
        return 1
    else:
         return 0
        
def get_piotroski_score():
    score = 0

    if ni > 0:
        score = score + 1
        print("ni",score)

    if roa() > 0:
        score = score + 1
        print("roa",score)

    if ocf() > 0:
        score = score + 1
        print("ocf",score)

    if ocf() > ni:
        score = score + 1
        print("ocf > ni",score)

    if lt_debt() > 0:
        score = score + 1
        print("ltd",score)

    if current_ratio() > 0:
        score = score + 1
        print("cr",score)

    if new_shares() > 0:
        score = score + 1
        print("ns",score)

    if gross_margin() > 0:
        score = score + 1
        print("gm",score)
    
    if at_ratio() > 0:
        score = score + 1
        print("atr",score)
    
    return score

# %%
p_score = get_piotroski_score()
print("")
print("Score is:", p_score )
# Out:
# ni 1
# roa 2
# ocf 3
# ocf > ni 4
# cr 5
# ns 6
# atr 7
#
# Score is: 7
